# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SuperStore_Sales_Dataset.csv")
df
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# ...

# %%
df.size
# Out:
# 135723

# %%
df.shape
# Out:
# (5901, 23)

# %%
df.head()
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 2              4920  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 3              3074  CA-2019-125206  03-01-2019  05-01-2019     First Class
# 4              8604  US-2019-116365  03-01-2019  08-01-2019  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
#           Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
# ...

# %%
df.describe()
# Out:
#        Row ID+O6G3A1:R6        Sales     Quantity       Profit  Returns  ind1  \
# count       5901.000000  5901.000000  5901.000000  5901.000000    287.0   0.0
# mean        5022.422471   265.345589     3.781901    29.700408      1.0   NaN
# std         2877.977184   474.260645     2.212917   259.589138      0.0   NaN
# min            1.000000     0.836000     1.000000 -6599.978000      1.0   NaN
# 25%         2486.000000    71.976000     2.000000     1.795500      1.0   NaN
# 50%         5091.000000   128.648000     3.000000     8.502500      1.0   NaN
# 75%         7456.000000   265.170000     5.000000    28.615000      1.0   NaN
# max         9994.000000  9099.930000    14.000000  8399.976000      1.0   NaN
#
#        ind2
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Row ID+O6G3A1:R6, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Profit, Returns, Payment Mode, ind1, ind2]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Convert Date

df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d-%m-%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%d-%m-%Y')

# %%
# Create new column

df['Year'] = df['Order Date'].dt.year

# %%
df['Month'] = df['Order Date'].dt.month_name()

# %%
df['Quarter'] = df['Order Date'].dt.quarter

# %%
df['Weekday'] = df['Order Date'].dt.day_name()

# %%
df['Ship Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
# EDA 

df.describe()
# Out:
#        Row ID+O6G3A1:R6                     Order Date  \
# count       5901.000000                           5901
# mean        5022.422471  2020-02-29 01:53:57.620742144
# min            1.000000            2019-01-01 00:00:00
# 25%         2486.000000            2019-09-11 00:00:00
# 50%         5091.000000            2020-03-16 00:00:00
# 75%         7456.000000            2020-09-14 00:00:00
# max         9994.000000            2020-12-31 00:00:00
# std         2877.977184                            NaN
#
#                            Ship Date        Sales     Quantity       Profit  \
# count                           5901  5901.000000  5901.000000  5901.000000
# mean   2020-03-04 00:08:47.097102336   265.345589     3.781901    29.700408
# min              2019-01-05 00:00:00     0.836000     1.000000 -6599.978000
# 25%              2019-09-15 00:00:00    71.976000     2.000000     1.795500
# 50%              2020-03-19 00:00:00   128.648000     3.000000     8.502500
# ...

# %%
# Total Sales

df['Sales'].sum()
# Out:
# np.float64(1565804.3232)

# %%
# Toatl Profit 

df['Profit'].sum()
# Out:
# np.float64(175262.1059)

# %%
# Average Sales

df['Sales'].mean()
# Out:
# np.float64(265.3455894255211)

# %%
# Median Sales

df['Sales'].median()
# Out:
# 128.648

# %%
df[['Sales','Profit','Quantity']].corr()
# Out:
#              Sales    Profit  Quantity
# Sales     1.000000  0.325915  0.202420
# Profit    0.325915  1.000000  0.074761
# Quantity  0.202420  0.074761  1.000000

# %%
# Category Analysis

df.groupby("Category")['Sales'].sum()
# Out:
# Category
# Furniture          451508.6452
# Office Supplies    643707.6870
# Technology         470587.9910
# Name: Sales, dtype: float64

# %%
# Sales by Category

category_sales = df.groupby('Category')['Sales'].sum().sort_values()

plt.figure(figsize=(8,5))
category_sales.plot(kind='bar')
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %%
# Region Analysis

df.groupby("Region")['Sales'].sum()
# Out:
# Region
# Central    341007.5242
# East       450234.6660
# South      252121.0810
# West       522441.0520
# Name: Sales, dtype: float64

# %%
# Sales by Region

region_sales = df.groupby('Region')['Sales'].sum()

plt.figure(figsize=(8,5))
region_sales.plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.show()

# %%
# State Analysis

df.groupby("State")['Sales'].sum()
# Out:
# State
# Alabama                  11884.5800
# Arizona                  22914.5560
# Arkansas                  9652.8300
# California              335190.2560
# Colorado                 29249.0640
# Connecticut              15034.6970
# Delaware                 12515.7030
# District of Columbia       419.8300
# Florida                  49914.9990
# Georgia                  37260.6900
# Idaho                     3180.0340
# Illinois                 64224.3300
# Indiana                  32039.2300
# Iowa                      3747.7200
# Kansas                    1837.2100
# Kentucky                 24352.7300
# Louisiana                 8369.3100
# Maine                      547.3300
# Maryland                 16090.1030
# Massachusetts            14302.3400
# Michigan                 48504.6840
# Minnesota                10808.6300
# Mississippi               8924.0200
# Missouri                 14641.9100
# Montana                   4622.2800
# Nebraska                  6108.7700
# ...

# %%
# Profit by Category

plt.figure(figsize=(8,5))
sns.barplot(data=df, x='Category', y='Profit', estimator=sum)
plt.title("Profit by Category")
plt.show()

# %%
# Segment Analysis

df.groupby("Segment")['Sales'].sum()
# Out:
# Segment
# Consumer       753002.1291
# Corporate      509743.1262
# Home Office    303059.0679
# Name: Sales, dtype: float64

# %%
# Payment Mode Analysis

df.groupby("Payment Mode")['Sales'].sum()
# Out:
# Payment Mode
# COD       667417.7513
# Cards     344393.1112
# Online    553993.4607
# Name: Sales, dtype: float64

# %%
# Ship Mode Analysis

df.groupby("Ship Mode")['Sales'].sum()
# Out:
# Ship Mode
# First Class       242936.7194
# Same Day           95958.5010
# Second Class      314508.0640
# Standard Class    912401.0388
# Name: Sales, dtype: float64

# %%
# Year wise trend

df.groupby("Year")['Sales'].sum()
# Out:
# Year
# 2019    5.646795e+05
# 2020    1.001125e+06
# Name: Sales, dtype: float64

# %%
# Monthly trend

df.groupby("Month")['Sales'].sum().sort_values(ascending = False)
# Out:
# Month
# December     244584.8918
# November     210372.7908
# September    193213.6769
# October      131584.6682
# May          117737.8382
# March        115945.2278
# June         109587.2597
# August       108454.2623
# July          99339.3790
# April         89557.5751
# January       73379.8050
# February      72046.9484
# Name: Sales, dtype: float64

# %%
# Top Products

df.groupby("Product Name")['Sales'].sum().sort_values(ascending = False).head(10)
# Out:
# Product Name
# 3D Systems Cube Printer, 2nd Generation, Magenta                               14334.890
# Canon imageCLASS 2200 Advanced Copier                                          14076.824
# Hewlett Packard LaserJet 3310 Copier                                           13837.732
# GBC DocuBind TL300 Electric Binding System                                     12890.258
# GBC DocuBind P400 Electric Binding System                                      12577.108
# Samsung Galaxy Mega 6.3                                                        12370.708
# Martin Yale Chadless Opener Electric Letter Opener                             12268.902
# HON 5400 Series Task Chairs for Big and Tall                                   11887.562
# Global Troy Executive Leather Low-Back Tilter                                  10217.894
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     9756.524
# Name: Sales, dtype: float64

# %%
# Bottom Products

df.groupby("Product Name")['Sales'].sum().sort_values(ascending=False).tail(10)
# Out:
# Product Name
# Grip Seal Envelopes                                                                  7.072
# Acme Design Line 8" Stainless Steel Bent Scissors w/Champagne Handles, 3-1/8" Cut    6.840
# Xerox 1983                                                                           5.980
# Binney & Smith inkTank Erasable Pocket Highlighter, Chisel Tip, Yellow               5.472
# Letter Slitter                                                                       5.040
# Wilson Jones Custom Binder Spines & Labels                                           4.896
# While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle                          4.730
# Eldon 100 Class Desk Accessories                                                     4.044
# Newell 32                                                                            2.880
# Avery 479                                                                            2.610
# Name: Sales, dtype: float64

# %%
df.groupby("Sub-Category")['Sales'].sum().sort_values(ascending = False).head(10)
# Out:
# Sub-Category
# Phones         196563.546
# Chairs         181945.998
# Binders        174978.390
# Storage        150341.318
# Accessories    122301.086
# Tables         119293.743
# Paper           99453.612
# Furnishings     92691.218
# Machines        91987.561
# Appliances      80305.247
# Name: Sales, dtype: float64

# %%
df.groupby("Sub-Category")['Sales'].sum().sort_values(ascending = False).tail(10)
# Out:
# Sub-Category
# Furnishings    92691.2180
# Machines       91987.5610
# Appliances     80305.2470
# Copiers        59735.7980
# Bookcases      57577.6862
# Art            50762.9760
# Supplies       36720.9860
# Labels         19397.4560
# Envelopes      16542.4640
# Fasteners      15205.2380
# Name: Sales, dtype: float64

# %%
df.to_csv('Retail_Store_Cleaned.csv', index=False)
